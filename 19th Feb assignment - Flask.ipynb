# %% [markdown]
# Q1. What is Flask Framework? What are the advantages of Flask Framework?
#
# Answer:
# Flask is a microframework for developers, designed to enable them to create and scale web apps quickly and simply. Explaining how they go about doing that will take a little more unraveling.
#
# Advantages of Flask
#
# 1. Scalable
# 2. Flexible
# 3. Easy to negotiate
# 4. Lightweight
# 5. Documentation
#
# **********

# %% [markdown]
# Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in
# Jupyter Notebook.

# %%
from flask import Flask

app = Flask(__name__)

@app.route("/")
def msg():
    return "<h1>Hello World!!<h1>"

if __name__ == "__main__":
    app.run(host="0.0.0.0")

# %% [markdown]
# ![Flask - Hello world.JPG](attachment:75bd766f-b7f7-4d36-8838-dd9bb1dea5f2.JPG)

# %% [markdown]
# Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”
# route to show the following details:
# Company Name: ABC Corporation
# Location: India
# Contact Detail: 999-999-9999
# Attach the screenshot of the output in Jupyter Notebook.

# %%
from flask import Flask

app = Flask(__name__)

@app.route("/welcome")
def msg1():
    return "<h1>“Welcome to ABC Corporation”<h1>"

@app.route("/")
def msg():
    return "<h1>Company Name: ABC Corporation<h1> \n <h1>Location: India<h1> \n <h1>Contact Detail: 999-999-9999<h1>"

if __name__ == "__main__":
    app.run(host="0.0.0.0")

# %% [markdown]
# ![image.png](attachment:e05b5120-51cd-4ed2-aadb-5506c7e6dfe1.png)

# %% [markdown]
# ![image.png](attachment:45d1c24d-062f-411c-93b7-39a7d970d7d5.png)

# %% [markdown]
# Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the
# url_for() function.
#
# Answer:
# url_for() function is used for dynamically building a URL for a specific function.
# The function accepts the name of a function as first argument, and one or more keyword arguments, each corresponding to the variable part of URL.

# %%
from flask import Flask, redirect, url_for

app = Flask(__name__)

@app.route("/welcome")
def welcome():
    return "<h1>“Welcome to ABC Corporation”<h1>"

@app.route("/details")
def det():
    return "<h1>Company Name: ABC Corporation<h1> \n <h1>Location: India<h1> \n <h1>Contact Detail: 999-999-9999<h1>"

@app.route('/home/<name>')
def home(name):
    if name == 'details':
        return redirect(url_for('det'))
    else:
        return redirect(url_for('welcome'))

if __name__ == "__main__":
    app.run(host="0.0.0.0")

# %% [markdown]
# ![image.png](attachment:aa90d989-4f1f-4000-86ec-2a98b57d3db4.png)

# %% [markdown]
# ![image.png](attachment:b1a35e2a-b1c3-4265-b1aa-89c858d351df.png)

# %% [markdown]
# ![image.png](attachment:c1a431c6-6af5-4aca-ba06-61f208052e2e.png)

# %% [markdown]
# ![image.png](attachment:323cc47b-8468-447d-8e93-cef639e7fea9.png)
