# %% [markdown]
# Q1. Explain GET and POST methods.
#
# Answer:
# Get and Post methods are the HTTP request methods used inside the <form> tag to send form data to the server.
# GET is used to request data from a specified resource through URL.
# POST method will request data through form.

# %% [markdown]
# *******************
# Q2. Why is request used in Flask?
#
# Answer: request object is used in Flask to access input data.

# %% [markdown]
# *******
# Q3. Why is redirect() used in Flask?
#
# Answer:
# The redirect() method of the Response interface returns a Response resulting in a redirect to the specified URL.
#
# ****
# Q4. What are templates in Flask? Why is the render_template() function used?
#
# Answer:
# Templates are files that contain static data as well as placeholders for dynamic data
# render_template() is a Flask function from the flask.templating package. render_template is used to generate output from a template file based on the Jinja2 engine that is found in the application's templates folder.

# %% [markdown]
# ****
# Q5. Create a simple API. Use Postman to test it. Attach the screenshot of the output in the Jupyter Notebook.

# %%
from flask import Flask, request, jsonify

app = Flask(__name__)

@app.route("/postman_action",methods=['POST'])
def addition():
    if (request.method == 'POST'):
        num1=int(request.json['num1'])
        num2=int(request.json['num2'])
        r=num1+num2
        result="Addition of " + str(num1) + " & " + str(num2) + " is " + str(r)
        return jsonify(result)

if __name__ == "__main__":
    app.run(host="0.0.0.0")

# %% [markdown]
# ![image.png](attachment:7739dd0f-f101-456b-9912-0110c3a7ab08.png)
