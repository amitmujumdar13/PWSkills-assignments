# %% [markdown]
# Q1. Explain why we have to use the Exception class while creating a Custom Exception.
#
# Answer: When we create a custom exception, by adding Exception class we can subclass any of the standard exception classes in order to define your own exception class.

# %% [markdown]
# Q2. Write a python program to print Python Exception Hierarchy.

# %%
# import inspect module
import inspect

def treeClass(cls, ind = 0):
    
      # print name of the class
    print ('-' * ind, cls.__name__)
      
    # iterating through subclasses
    for i in cls.__subclasses__():
        treeClass(i, ind + 3)
        
treeClass(BaseException)
# Out:
#  BaseException
# --- Exception
# ------ TypeError
# --------- FloatOperation
# --------- MultipartConversionError
# ------ StopAsyncIteration
# ------ StopIteration
# ------ ImportError
# --------- ModuleNotFoundError
# --------- ZipImportError
# ------ OSError
# --------- ConnectionError
# ------------ BrokenPipeError
# ------------ ConnectionAbortedError
# ------------ ConnectionRefusedError
# ------------ ConnectionResetError
# --------------- RemoteDisconnected
# --------- BlockingIOError
# --------- ChildProcessError
# --------- FileExistsError
# --------- FileNotFoundError
# --------- IsADirectoryError
# --------- NotADirectoryError
# --------- InterruptedError
# ------------ InterruptedSystemCall
# --------- PermissionError
# --------- ProcessLookupError
# --------- TimeoutError
# --------- UnsupportedOperation
# --------- itimer_error
# --------- herror
# --------- gaierror
# --------- SSLError
# ------------ SSLCertVerificationError
# ------------ SSLZeroReturnError
# ...

# %% [markdown]
# Q3. What errors are defined in the ArithmeticError class? Explain any two with an example.

# %% [markdown]
# Answer:
# Below are the errors under ArithmaticError
#
# FloatingPointError
# OverflowError
# ZeroDivisionError
# DecimalException

# %%
# example for OverflowError

j = 5.0

for i in range(1, 1000):
    j = j**i
    print(j)
# Out:
# 5.0
# 25.0
# 15625.0
# 5.960464477539062e+16
# 7.52316384526264e+83
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[1], line 6
#       3 j = 5.0
#       5 for i in range(1, 1000):
# ----> 6     j = j**i
#       7     print(j)
#
# OverflowError: (34, 'Numerical result out of range')

# %%
# example for ZeroDivisionError

j=0
div=10/j
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[2], line 4
#       1 # example for ZeroDivisionError
#       3 j=0
# ----> 4 div=10/j
#
# ZeroDivisionError: division by zero

# %% [markdown]
# Q4. Why LookupError class is used? Explain with an example KeyError and IndexError.
#
# _____________________________________
# Answer: The base class for the exceptions that are raised when a key or index used on a mapping or sequence is invalid: IndexError, KeyError.

# %%
ls={"name":"Amit","EmpID":"1234","city":"Pune"}


## key "state" is invalid, hence KeyError is thrown
ls["state"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 3
#       1 ls={"name":"Amit","EmpID":"1234","city":"Pune"}
# ----> 3 ls["state"]
#
# KeyError: 'state'

# %%
## index is out of bounds hence IndexError

ls["city"][4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 ls["city"][4]
#
# IndexError: string index out of range

# %% [markdown]
# Q5. Explain ImportError. What is ModuleNotFoundError?
#
# Answer: In python, we can import other ,modules with import statement. If requested module is not found then ModuleNotFoundError is thrown.
#
# **********************

# %% [markdown]
# Q6. List down some best practices for exception handling in python.
#
# Answer:
# 1. Precise Exception Catch always
# 2. Only include possible exceptions, avoid unneccessary exception handling
# 3. Try to include specific exception only
# 4. Always use try. except..else combination without missing any block.
